# %% [markdown]
# # Onboarding SI Flood Model

# %%
import zarr
import os

from hazard.sources.osc_zarr import OscZarr

import logging
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
DATA_DIR = "../data"

# %%
from cvar.hazard_models.si_poplave import SIFloodIndicatorModel, SIPoplaveSource

# %%
# Model
model = SIFloodIndicatorModel()

# Source
source = SIPoplaveSource(
    source_dir="/Users/klemenkubelj/Documents/school/graduate/masters/data/si_karte_globin/merged"
)

# Target - local
test_output_dir = os.path.join(DATA_DIR, "si_poplave_onboard_test")
if not os.path.exists(test_output_dir):
    os.makedirs(test_output_dir)
store = zarr.DirectoryStore(os.path.join(test_output_dir, "hazard", "hazard.zarr"))
target = OscZarr(store=store, write_xarray_compatible_zarr=True)

# %%
print("SOURCE: ", source)
print("TARGET: ", target)
# Out:
# SOURCE:  <cvar.hazard_models.si_poplave.SIPoplaveSource object at 0x14946bcd0>
# TARGET:  <hazard.sources.osc_zarr.OscZarr object at 0x1497c58a0>

# %%
items = model.batch_items()
item = items[0]

# %%
source

# %%
model.run_single(
    item=item,
    source=source,
    target=target,
    client=None
)
# Out:
# SOURCE:  <cvar.hazard_models.si_poplave.SIPoplaveSource object at 0x14946bcd0>
# TARGET:  <hazard.sources.osc_zarr.OscZarr object at 0x1497c58a0>
# type:  <class 'cvar.hazard_models.si_poplave.SIPoplaveSource'>
# Copying return period 1/1
# Loading fname:  globine_q10.tif
# Loading file:  /Users/klemenkubelj/Documents/school/graduate/masters/data/si_karte_globin/merged/globine_q10.tif
# done

# %%
items
# Out:
# [BatchItem(path='inundation/si_poplave/v1/si_poplave', scenario='historical', year=1971, filename_return_period='globine_q{return_period}.tif')]

# %% [markdown]
# ### Test rasterization
